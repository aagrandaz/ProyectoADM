# %% [markdown]
# # Etapa 6: Inferencia, Ranking y Recomendaciones Comerciales
#
# Este cuaderno realiza el scoring o predicción del set de prueba para cada cliente y producto candidato, ordena las probabilidades para generar rankings internos por cliente, y exporta la recomendación óptima (Top-1) para cada uno.

# %%
import sys
import os
from pathlib import Path

# Resolver la ruta raíz del proyecto de forma dinámica y portable
try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    import subprocess
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "pyarrow", "pandas", "scikit-learn", "joblib", "numpy"])
    print("Dependencias instaladas en Colab.")
    
    # Intentar montar Google Drive automáticamente si no está montado
    if not Path('/content/drive').exists():
        try:
            from google.colab import drive
            drive.mount('/content/drive')
        except Exception as e:
            print("No se pudo montar Drive automáticamente. Por favor, móntelo en el panel izquierdo de Colab.")

current_dir = Path(os.getcwd()).resolve()
if IN_COLAB:
    # Rutas de búsqueda comunes en Google Drive y Colab
    possible_paths = [
        Path('/content/drive/MyDrive/Colab Notebooks/Proyecto'),
        Path('/content/drive/MyDrive/Proyecto'),
        Path('/content/Proyecto'),
        Path('/content')
    ]
    for p in possible_paths:
        if (p / "notebooks").exists():
            current_dir = p / "notebooks"
            break

if current_dir.name == "notebooks":
    PROJECT_ROOT = current_dir.parent
else:
    PROJECT_ROOT = current_dir

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %% [markdown]
# ## 1. Lanzar Inferencia de Productos

# %%
from src.predict import make_predictions

make_predictions(PROJECT_ROOT)
# Out:
# [Inferencia] Cargando modelo serializado y dataset de predicción...
# [Inferencia] Calculando probabilidades de adquisición...
# [Inferencia] Generando ranking de recomendaciones por cliente...
# [Inferencia] Tabla completa de predicciones guardada en: /Volumes/HD/0.2.Sistemas_de_Informacion_UG/11vo-semestre/ANÁLISIS DE DATOS MASIVO/Proyecto/data/gold/predicciones_next_best_product.parquet (16000 filas)
# [Inferencia] Tabla de recomendaciones Top-1 guardada en: /Volumes/HD/0.2.Sistemas_de_Informacion_UG/11vo-semestre/ANÁLISIS DE DATOS MASIVO/Proyecto/data/gold/recomendaciones_next_best_product.parquet (1000 filas)
# [Inferencia] Flujo de scoring y predicción completado exitosamente.

# %% [markdown]
# ## 2. Mostrar la Recomendación Comercial Final para Clientes
# Cargamos la tabla de recomendaciones finales generada para el consumo comercial.

# %%
import pandas as pd

recs_path = PROJECT_ROOT / "data" / "gold" / "recomendaciones_next_best_product.parquet"
recs_df = pd.read_parquet(recs_path)

print(f"Recomendaciones generadas para {recs_df.shape[0]} clientes únicos:")
display(recs_df.head(10))
# Out:
# Recomendaciones generadas para 1000 clientes únicos:
#    id_cliente fecha_corte  id_producto_candidato producto_recomendado  \
# 0       15889  2016-06-28                     15             Hipoteca
# 1     1169510  2016-06-28                     15             Hipoteca
# 2     1169512  2016-06-28                     15             Hipoteca
# 3     1169514  2016-06-28                     15             Hipoteca
# 4     1169516  2016-06-28                     15             Hipoteca
# 5     1169518  2016-06-28                     16    Plan de pensiones
# 6     1169520  2016-06-28                     15             Hipoteca
# 7     1169522  2016-06-28                     15             Hipoteca
# 8     1169523  2016-06-28                     15             Hipoteca
# 9     1169525  2016-06-28                     15             Hipoteca
#
#   categoria_producto  probabilidad  posicion_ranking
# 0            Crédito      0.095721                 1
# 1            Crédito      0.085575                 1
# 2            Crédito      0.080227                 1
# 3            Crédito      0.127028                 1
# 4            Crédito      0.175163                 1
# 5          Inversión      0.166906                 1
# 6            Crédito      0.080227                 1
# 7            Crédito      0.220699                 1
# 8            Crédito      0.093216                 1
# 9            Crédito      0.066661                 1
